# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense, Add
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

def residual_block(x, filters, kernel_size=3, stride=1):
    res = Conv2D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    res = BatchNormalization()(res)
    res = ReLU()(res)

    res = Conv2D(filters, kernel_size=kernel_size, strides=1, padding='same')(res)
    res = BatchNormalization()(res)

    if x.shape[-1] != filters or stride != 1:
        x = Conv2D(filters, kernel_size=1, strides=stride, padding='same')(x)
        x = BatchNormalization()(x)

    x = Add()([x, res])
    x = ReLU()(x)
    return x

def create_resnet_cifar():
    input = Input(shape=(32, 32, 3))

    x = Conv2D(64, kernel_size=3, strides=1, padding='same')(input)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    num_blocks_list = [3, 3, 3]  # Number of residual blocks per stage
    filters_list = [64, 128, 256]

    for stage, (num_blocks, filters) in enumerate(zip(num_blocks_list, filters_list)):
        for block in range(num_blocks):
            stride = 2 if block == 0 and stage != 0 else 1
            x = residual_block(x, filters, stride=stride)

    x = GlobalAveragePooling2D()(x)
    output = Dense(100, activation='softmax')(x)  # 100 classes for CIFAR-100

    model = Model(inputs=input, outputs=output)
    return model

# Load CIFAR-100 dataset
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

# Split the training data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_val = x_val.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

# Create the ResNet model for CIFAR-100
model = create_resnet_cifar()

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with a specified number of epochs using the train-validation split
epochs = 10  # Change this value to set the desired number of epochs
model.fit(x_train, y_train, epochs=epochs, batch_size=64, validation_data=(x_val, y_val))

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 5s 0us/step
# Epoch 1/10
# 625/625 [==============================] - 67s 75ms/step - loss: 3.8234 - accuracy: 0.1159 - val_loss: 3.6326 - val_accuracy: 0.1418
# Epoch 2/10
# 625/625 [==============================] - 47s 76ms/step - loss: 3.0075 - accuracy: 0.2449 - val_loss: 3.2253 - val_accuracy: 0.2161
# Epoch 3/10
# 625/625 [==============================] - 45s 73ms/step - loss: 2.4260 - accuracy: 0.3585 - val_loss: 2.5871 - val_accuracy: 0.3325
# Epoch 4/10
# 625/625 [==============================] - 46s 73ms/step - loss: 2.0311 - accuracy: 0.4446 - val_loss: 2.3189 - val_accuracy: 0.3957
# Epoch 5/10
# 625/625 [==============================] - 47s 76ms/step - loss: 1.7377 - accuracy: 0.5152 - val_loss: 2.2080 - val_accuracy: 0.4233
# Epoch 6/10
# 625/625 [==============================] - 48s 77ms/step - loss: 1.4998 - accuracy: 0.5724 - val_loss: 1.9954 - val_accuracy: 0.4652
# Epoch 7/10
# 625/625 [==============================] - 46s 73ms/step - loss: 1.2951 - accuracy: 0.6224 - val_loss: 2.3056 - val_accuracy: 0.4280
# Epoch 8/10
# 625/625 [==============================] - 46s 73ms/step - loss: 1.1027 - accuracy: 0.6762 - val_loss: 1.9680 - val_accuracy: 0.4888
# Epoch 9/10
# 625/625 [==============================] - 46s 73ms/step - loss: 0.9255 - accuracy: 0.7205 - val_loss: 2.1940 - val_accuracy: 0.4767
# Epoch 10/10
# 625/625 [==============================] - 47s 76ms/step - loss: 0.7393 - accuracy: 0.7722 - val_loss: 2.3092 - val_accuracy: 0.4702
# 313/313 [==============================] - 4s 13ms/step - loss: 2.3103 - accuracy: 0.4620
# Test accuracy: 0.4620000123977661

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense, Add
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

def residual_block(x, filters, kernel_size=3, stride=1):
    res = Conv2D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    res = BatchNormalization()(res)
    res = ReLU()(res)

    res = Conv2D(filters, kernel_size=kernel_size, strides=1, padding='same')(res)
    res = BatchNormalization()(res)

    if x.shape[-1] != filters or stride != 1:
        x = Conv2D(filters, kernel_size=1, strides=stride, padding='same')(x)
        x = BatchNormalization()(x)

    x = Add()([x, res])
    x = ReLU()(x)
    return x

def create_resnet_cifar():
    input = Input(shape=(32, 32, 3))

    x = Conv2D(64, kernel_size=3, strides=1, padding='same')(input)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    num_blocks_list = [3, 3, 3]  # Number of residual blocks per stage
    filters_list = [64, 128, 256]

    for stage, (num_blocks, filters) in enumerate(zip(num_blocks_list, filters_list)):
        for block in range(num_blocks):
            stride = 2 if block == 0 and stage != 0 else 1
            x = residual_block(x, filters, stride=stride)

    x = GlobalAveragePooling2D()(x)
    output = Dense(100, activation='softmax')(x)  # 100 classes for CIFAR-100

    model = Model(inputs=input, outputs=output)
    return model

# Load CIFAR-100 dataset
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

# Split the training data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=10)

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_val = x_val.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

# Create the ResNet model for CIFAR-100
model = create_resnet_cifar()

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with a specified number of epochs using the train-validation split
epochs = 20
model.fit(x_train, y_train, epochs=epochs, batch_size=64, validation_data=(x_val, y_val))

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Epoch 1/20
# 625/625 [==============================] - 57s 74ms/step - loss: 3.8669 - accuracy: 0.1049 - val_loss: 3.8945 - val_accuracy: 0.1226
# Epoch 2/20
# 625/625 [==============================] - 47s 75ms/step - loss: 3.0838 - accuracy: 0.2324 - val_loss: 3.5842 - val_accuracy: 0.1702
# Epoch 3/20
# 625/625 [==============================] - 45s 72ms/step - loss: 2.4894 - accuracy: 0.3486 - val_loss: 2.6564 - val_accuracy: 0.3209
# Epoch 4/20
# 625/625 [==============================] - 47s 75ms/step - loss: 2.0744 - accuracy: 0.4382 - val_loss: 2.8092 - val_accuracy: 0.3201
# Epoch 5/20
# 625/625 [==============================] - 45s 72ms/step - loss: 1.7758 - accuracy: 0.5065 - val_loss: 2.3270 - val_accuracy: 0.4041
# Epoch 6/20
# 625/625 [==============================] - 47s 76ms/step - loss: 1.5306 - accuracy: 0.5648 - val_loss: 2.2358 - val_accuracy: 0.4079
# Epoch 7/20
# 625/625 [==============================] - 45s 72ms/step - loss: 1.3137 - accuracy: 0.6207 - val_loss: 2.2725 - val_accuracy: 0.4294
# Epoch 8/20
# 625/625 [==============================] - 45s 72ms/step - loss: 1.1279 - accuracy: 0.6667 - val_loss: 2.4123 - val_accuracy: 0.4390
# Epoch 9/20
# 625/625 [==============================] - 45s 72ms/step - loss: 0.9427 - accuracy: 0.7151 - val_loss: 2.1015 - val_accuracy: 0.4728
# Epoch 10/20
# 625/625 [==============================] - 47s 75ms/step - loss: 0.7593 - accuracy: 0.7676 - val_loss: 1.9812 - val_accuracy: 0.5155
# Epoch 11/20
# 625/625 [==============================] - 45s 72ms/step - loss: 0.5915 - accuracy: 0.8152 - val_loss: 2.1735 - val_accuracy: 0.4973
# Epoch 12/20
# 625/625 [==============================] - 47s 75ms/step - loss: 0.4484 - accuracy: 0.8583 - val_loss: 2.2841 - val_accuracy: 0.5041
# Epoch 13/20
# 625/625 [==============================] - 45s 72ms/step - loss: 0.3303 - accuracy: 0.8942 - val_loss: 2.9127 - val_accuracy: 0.4606
# Epoch 14/20
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2456 - accuracy: 0.9242 - val_loss: 2.8137 - val_accuracy: 0.4775
# Epoch 15/20
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2243 - accuracy: 0.9287 - val_loss: 2.7231 - val_accuracy: 0.4902
# Epoch 16/20
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1870 - accuracy: 0.9412 - val_loss: 3.0784 - val_accuracy: 0.4645
# Epoch 17/20
# 625/625 [==============================] - 47s 75ms/step - loss: 0.1574 - accuracy: 0.9503 - val_loss: 2.6965 - val_accuracy: 0.5066
# Epoch 18/20
# 625/625 [==============================] - 47s 75ms/step - loss: 0.1512 - accuracy: 0.9518 - val_loss: 3.2624 - val_accuracy: 0.4799
# Epoch 19/20
# 625/625 [==============================] - 47s 75ms/step - loss: 0.1339 - accuracy: 0.9564 - val_loss: 2.9331 - val_accuracy: 0.5156
# Epoch 20/20
# 625/625 [==============================] - 47s 75ms/step - loss: 0.1222 - accuracy: 0.9605 - val_loss: 3.0513 - val_accuracy: 0.5076
# 313/313 [==============================] - 4s 12ms/step - loss: 3.0773 - accuracy: 0.5093
# Test accuracy: 0.5092999935150146

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense, Add
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

def residual_block(x, filters, kernel_size=3, stride=1):
    res = Conv2D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    res = BatchNormalization()(res)
    res = ReLU()(res)

    res = Conv2D(filters, kernel_size=kernel_size, strides=1, padding='same')(res)
    res = BatchNormalization()(res)

    if x.shape[-1] != filters or stride != 1:
        x = Conv2D(filters, kernel_size=1, strides=stride, padding='same')(x)
        x = BatchNormalization()(x)

    x = Add()([x, res])
    x = ReLU()(x)
    return x

def create_resnet_cifar():
    input = Input(shape=(32, 32, 3))

    x = Conv2D(64, kernel_size=3, strides=1, padding='same')(input)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    num_blocks_list = [3, 3, 3]  # Number of residual blocks per stage
    filters_list = [64, 128, 256]

    for stage, (num_blocks, filters) in enumerate(zip(num_blocks_list, filters_list)):
        for block in range(num_blocks):
            stride = 2 if block == 0 and stage != 0 else 1
            x = residual_block(x, filters, stride=stride)

    x = GlobalAveragePooling2D()(x)
    output = Dense(100, activation='softmax')(x)  # 100 classes for CIFAR-100

    model = Model(inputs=input, outputs=output)
    return model

# Load CIFAR-100 dataset
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

# Split the training data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=12)

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_val = x_val.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

# Create the ResNet model for CIFAR-100
model = create_resnet_cifar()

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with a specified number of epochs using the train-validation split
epochs = 20
model.fit(x_train, y_train, epochs=epochs, batch_size=100, validation_data=(x_val, y_val))

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Epoch 1/20
# 400/400 [==============================] - 57s 113ms/step - loss: 3.6533 - accuracy: 0.1403 - val_loss: 4.7002 - val_accuracy: 0.0806
# Epoch 2/20
# 400/400 [==============================] - 43s 108ms/step - loss: 2.7413 - accuracy: 0.2972 - val_loss: 3.8345 - val_accuracy: 0.2034
# Epoch 3/20
# 400/400 [==============================] - 46s 114ms/step - loss: 2.2034 - accuracy: 0.4105 - val_loss: 2.7897 - val_accuracy: 0.3331
# Epoch 4/20
# 400/400 [==============================] - 44s 110ms/step - loss: 1.8411 - accuracy: 0.4934 - val_loss: 2.4333 - val_accuracy: 0.3779
# Epoch 5/20
# 400/400 [==============================] - 44s 110ms/step - loss: 1.5779 - accuracy: 0.5560 - val_loss: 2.2545 - val_accuracy: 0.4229
# Epoch 6/20
# 400/400 [==============================] - 46s 115ms/step - loss: 1.3412 - accuracy: 0.6123 - val_loss: 2.1815 - val_accuracy: 0.4360
# Epoch 7/20
# 400/400 [==============================] - 46s 115ms/step - loss: 1.1308 - accuracy: 0.6654 - val_loss: 2.2868 - val_accuracy: 0.4363
# Epoch 8/20
# 400/400 [==============================] - 46s 115ms/step - loss: 0.9455 - accuracy: 0.7170 - val_loss: 2.2330 - val_accuracy: 0.4647
# Epoch 9/20
# 400/400 [==============================] - 44s 110ms/step - loss: 0.7491 - accuracy: 0.7700 - val_loss: 2.2051 - val_accuracy: 0.4980
# Epoch 10/20
# 400/400 [==============================] - 44s 111ms/step - loss: 0.5824 - accuracy: 0.8204 - val_loss: 2.2203 - val_accuracy: 0.4709
# Epoch 11/20
# 400/400 [==============================] - 46s 116ms/step - loss: 0.4291 - accuracy: 0.8673 - val_loss: 2.5106 - val_accuracy: 0.4799
# Epoch 12/20
# 400/400 [==============================] - 46s 116ms/step - loss: 0.3085 - accuracy: 0.9059 - val_loss: 2.6243 - val_accuracy: 0.4792
# Epoch 13/20
# 400/400 [==============================] - 46s 115ms/step - loss: 0.2246 - accuracy: 0.9319 - val_loss: 2.9016 - val_accuracy: 0.4570
# Epoch 14/20
# 400/400 [==============================] - 46s 116ms/step - loss: 0.1884 - accuracy: 0.9440 - val_loss: 3.1003 - val_accuracy: 0.4644
# Epoch 15/20
# 400/400 [==============================] - 44s 111ms/step - loss: 0.1678 - accuracy: 0.9472 - val_loss: 3.3541 - val_accuracy: 0.4413
# Epoch 16/20
# 400/400 [==============================] - 46s 116ms/step - loss: 0.1519 - accuracy: 0.9531 - val_loss: 2.9501 - val_accuracy: 0.4628
# Epoch 17/20
# 400/400 [==============================] - 44s 111ms/step - loss: 0.1511 - accuracy: 0.9519 - val_loss: 2.8983 - val_accuracy: 0.4968
# Epoch 18/20
# 400/400 [==============================] - 44s 111ms/step - loss: 0.1055 - accuracy: 0.9684 - val_loss: 2.8320 - val_accuracy: 0.4955
# Epoch 19/20
# 400/400 [==============================] - 44s 111ms/step - loss: 0.1108 - accuracy: 0.9661 - val_loss: 3.8813 - val_accuracy: 0.4335
# Epoch 20/20
# 400/400 [==============================] - 46s 116ms/step - loss: 0.1216 - accuracy: 0.9615 - val_loss: 3.8079 - val_accuracy: 0.4388
# 313/313 [==============================] - 4s 13ms/step - loss: 3.7561 - accuracy: 0.4484
# Test accuracy: 0.44839999079704285

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense, Add
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

def residual_block(x, filters, kernel_size=3, stride=1):
    res = Conv2D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    res = BatchNormalization()(res)
    res = ReLU()(res)

    res = Conv2D(filters, kernel_size=kernel_size, strides=1, padding='same')(res)
    res = BatchNormalization()(res)

    if x.shape[-1] != filters or stride != 1:
        x = Conv2D(filters, kernel_size=1, strides=stride, padding='same')(x)
        x = BatchNormalization()(x)

    x = Add()([x, res])
    x = ReLU()(x)
    return x

def create_resnet_cifar():
    input = Input(shape=(32, 32, 3))

    x = Conv2D(64, kernel_size=3, strides=1, padding='same')(input)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    num_blocks_list = [3, 3, 3]  # Number of residual blocks per stage
    filters_list = [64, 128, 256]

    for stage, (num_blocks, filters) in enumerate(zip(num_blocks_list, filters_list)):
        for block in range(num_blocks):
            stride = 2 if block == 0 and stage != 0 else 1
            x = residual_block(x, filters, stride=stride)

    x = GlobalAveragePooling2D()(x)
    output = Dense(100, activation='softmax')(x)  # 100 classes for CIFAR-100

    model = Model(inputs=input, outputs=output)
    return model

# Load CIFAR-100 dataset
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

# Split the training data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=14)

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_val = x_val.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

# Create the ResNet model for CIFAR-100
model = create_resnet_cifar()

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with a specified number of epochs using the train-validation split
epochs = 30
model.fit(x_train, y_train, epochs=epochs, batch_size=100, validation_data=(x_val, y_val))

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Epoch 1/30
# 400/400 [==============================] - 57s 114ms/step - loss: 3.6604 - accuracy: 0.1404 - val_loss: 4.2910 - val_accuracy: 0.0904
# Epoch 2/30
# 400/400 [==============================] - 45s 114ms/step - loss: 2.7403 - accuracy: 0.3011 - val_loss: 3.1405 - val_accuracy: 0.2512
# Epoch 3/30
# 400/400 [==============================] - 44s 109ms/step - loss: 2.2023 - accuracy: 0.4078 - val_loss: 2.3262 - val_accuracy: 0.3863
# Epoch 4/30
# 400/400 [==============================] - 44s 110ms/step - loss: 1.8429 - accuracy: 0.4918 - val_loss: 2.7239 - val_accuracy: 0.3526
# Epoch 5/30
# 400/400 [==============================] - 44s 110ms/step - loss: 1.5750 - accuracy: 0.5526 - val_loss: 2.3440 - val_accuracy: 0.3997
# Epoch 6/30
# 400/400 [==============================] - 44s 110ms/step - loss: 1.3402 - accuracy: 0.6141 - val_loss: 2.3902 - val_accuracy: 0.4158
# Epoch 7/30
# 400/400 [==============================] - 46s 115ms/step - loss: 1.1461 - accuracy: 0.6646 - val_loss: 1.9486 - val_accuracy: 0.4994
# Epoch 8/30
# 400/400 [==============================] - 44s 110ms/step - loss: 0.9450 - accuracy: 0.7182 - val_loss: 2.3103 - val_accuracy: 0.4574
# Epoch 9/30
# 400/400 [==============================] - 44s 111ms/step - loss: 0.7583 - accuracy: 0.7705 - val_loss: 2.1892 - val_accuracy: 0.4731
# Epoch 10/30
# 400/400 [==============================] - 46s 116ms/step - loss: 0.5890 - accuracy: 0.8184 - val_loss: 2.3113 - val_accuracy: 0.4985
# Epoch 11/30
# 400/400 [==============================] - 46s 116ms/step - loss: 0.4329 - accuracy: 0.8652 - val_loss: 2.6399 - val_accuracy: 0.4653
# Epoch 12/30
# 400/400 [==============================] - 44s 110ms/step - loss: 0.3110 - accuracy: 0.9053 - val_loss: 2.7815 - val_accuracy: 0.4479
# Epoch 13/30
# 400/400 [==============================] - 44s 111ms/step - loss: 0.2237 - accuracy: 0.9324 - val_loss: 2.3619 - val_accuracy: 0.5173
# Epoch 14/30
# 400/400 [==============================] - 45s 112ms/step - loss: 0.1716 - accuracy: 0.9492 - val_loss: 2.8443 - val_accuracy: 0.4927
# Epoch 15/30
# 400/400 [==============================] - 47s 116ms/step - loss: 0.1738 - accuracy: 0.9461 - val_loss: 3.0395 - val_accuracy: 0.4605
# Epoch 16/30
# 400/400 [==============================] - 45s 111ms/step - loss: 0.1479 - accuracy: 0.9548 - val_loss: 3.0451 - val_accuracy: 0.4757
# Epoch 17/30
# 400/400 [==============================] - 47s 116ms/step - loss: 0.1382 - accuracy: 0.9563 - val_loss: 3.2498 - val_accuracy: 0.4497
# Epoch 18/30
# 400/400 [==============================] - 45s 111ms/step - loss: 0.1246 - accuracy: 0.9615 - val_loss: 3.2105 - val_accuracy: 0.4696
# Epoch 19/30
# 400/400 [==============================] - 47s 116ms/step - loss: 0.1117 - accuracy: 0.9657 - val_loss: 2.9059 - val_accuracy: 0.5049
# Epoch 20/30
# 400/400 [==============================] - 45s 112ms/step - loss: 0.1024 - accuracy: 0.9671 - val_loss: 3.3663 - val_accuracy: 0.4787
# Epoch 21/30
# 400/400 [==============================] - 45s 111ms/step - loss: 0.0888 - accuracy: 0.9730 - val_loss: 3.6639 - val_accuracy: 0.4631
# Epoch 22/30
# 400/400 [==============================] - 45s 112ms/step - loss: 0.1129 - accuracy: 0.9632 - val_loss: 3.9115 - val_accuracy: 0.4396
# Epoch 23/30
# 400/400 [==============================] - 47s 116ms/step - loss: 0.0947 - accuracy: 0.9689 - val_loss: 2.8247 - val_accuracy: 0.5323
# Epoch 24/30
# 400/400 [==============================] - 45s 112ms/step - loss: 0.0780 - accuracy: 0.9750 - val_loss: 3.2278 - val_accuracy: 0.5083
# Epoch 25/30
# 400/400 [==============================] - 47s 116ms/step - loss: 0.0793 - accuracy: 0.9750 - val_loss: 3.0778 - val_accuracy: 0.5131
# Epoch 26/30
# 400/400 [==============================] - 45s 111ms/step - loss: 0.0891 - accuracy: 0.9719 - val_loss: 3.4973 - val_accuracy: 0.4812
# Epoch 27/30
# 400/400 [==============================] - 46s 116ms/step - loss: 0.0813 - accuracy: 0.9736 - val_loss: 3.6221 - val_accuracy: 0.4851
# Epoch 28/30
# 400/400 [==============================] - 46s 116ms/step - loss: 0.0669 - accuracy: 0.9786 - val_loss: 3.3519 - val_accuracy: 0.5171
# Epoch 29/30
# 400/400 [==============================] - 44s 111ms/step - loss: 0.0565 - accuracy: 0.9825 - val_loss: 3.2735 - val_accuracy: 0.5055
# Epoch 30/30
# 400/400 [==============================] - 47s 116ms/step - loss: 0.0623 - accuracy: 0.9802 - val_loss: 3.6532 - val_accuracy: 0.4865
# 313/313 [==============================] - 5s 13ms/step - loss: 3.6197 - accuracy: 0.4940
# Test accuracy: 0.49399998784065247

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense, Add
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

def residual_block(x, filters, kernel_size=3, stride=1):
    res = Conv2D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    res = BatchNormalization()(res)
    res = ReLU()(res)

    res = Conv2D(filters, kernel_size=kernel_size, strides=1, padding='same')(res)
    res = BatchNormalization()(res)

    if x.shape[-1] != filters or stride != 1:
        x = Conv2D(filters, kernel_size=1, strides=stride, padding='same')(x)
        x = BatchNormalization()(x)

    x = Add()([x, res])
    x = ReLU()(x)
    return x

def create_resnet_cifar():
    input = Input(shape=(32, 32, 3))

    x = Conv2D(64, kernel_size=3, strides=1, padding='same')(input)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    num_blocks_list = [3, 3, 3]  # Number of residual blocks per stage
    filters_list = [64, 128, 256]

    for stage, (num_blocks, filters) in enumerate(zip(num_blocks_list, filters_list)):
        for block in range(num_blocks):
            stride = 2 if block == 0 and stage != 0 else 1
            x = residual_block(x, filters, stride=stride)

    x = GlobalAveragePooling2D()(x)
    output = Dense(100, activation='softmax')(x)  # 100 classes for CIFAR-100

    model = Model(inputs=input, outputs=output)
    return model

# Load CIFAR-100 dataset
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

# Split the training data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=16)

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_val = x_val.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

# Create the ResNet model for CIFAR-100
model = create_resnet_cifar()

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with a specified number of epochs using the train-validation split
epochs = 40
model.fit(x_train, y_train, epochs=epochs, batch_size=100, validation_data=(x_val, y_val))

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Epoch 1/40
# 400/400 [==============================] - 55s 110ms/step - loss: 3.6120 - accuracy: 0.1496 - val_loss: 4.3215 - val_accuracy: 0.1219
# Epoch 2/40
# 400/400 [==============================] - 44s 109ms/step - loss: 2.6877 - accuracy: 0.3092 - val_loss: 2.8095 - val_accuracy: 0.2913
# Epoch 3/40
# 400/400 [==============================] - 46s 115ms/step - loss: 2.1393 - accuracy: 0.4236 - val_loss: 3.1376 - val_accuracy: 0.2998
# Epoch 4/40
# 400/400 [==============================] - 44s 110ms/step - loss: 1.7931 - accuracy: 0.5056 - val_loss: 2.2761 - val_accuracy: 0.4008
# Epoch 5/40
# 400/400 [==============================] - 44s 110ms/step - loss: 1.5197 - accuracy: 0.5709 - val_loss: 2.3988 - val_accuracy: 0.4166
# Epoch 6/40
# 400/400 [==============================] - 44s 110ms/step - loss: 1.2928 - accuracy: 0.6255 - val_loss: 2.6140 - val_accuracy: 0.3722
# Epoch 7/40
# 400/400 [==============================] - 44s 111ms/step - loss: 1.0880 - accuracy: 0.6800 - val_loss: 2.3581 - val_accuracy: 0.4311
# Epoch 8/40
# 400/400 [==============================] - 44s 111ms/step - loss: 0.8879 - accuracy: 0.7343 - val_loss: 2.0191 - val_accuracy: 0.4825
# Epoch 9/40
# 400/400 [==============================] - 44s 111ms/step - loss: 0.6865 - accuracy: 0.7914 - val_loss: 2.2941 - val_accuracy: 0.4673
# Epoch 10/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.5194 - accuracy: 0.8416 - val_loss: 2.4187 - val_accuracy: 0.4526
# Epoch 11/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.3754 - accuracy: 0.8857 - val_loss: 2.5521 - val_accuracy: 0.4753
# Epoch 12/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.2581 - accuracy: 0.9223 - val_loss: 2.5343 - val_accuracy: 0.4893
# Epoch 13/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.1986 - accuracy: 0.9391 - val_loss: 3.1350 - val_accuracy: 0.4492
# Epoch 14/40
# 400/400 [==============================] - 46s 115ms/step - loss: 0.1702 - accuracy: 0.9499 - val_loss: 2.8475 - val_accuracy: 0.4614
# Epoch 15/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.1676 - accuracy: 0.9467 - val_loss: 3.1040 - val_accuracy: 0.4822
# Epoch 16/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.1472 - accuracy: 0.9548 - val_loss: 3.3395 - val_accuracy: 0.4405
# Epoch 17/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.1148 - accuracy: 0.9654 - val_loss: 3.6618 - val_accuracy: 0.4374
# Epoch 18/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.1144 - accuracy: 0.9642 - val_loss: 3.5605 - val_accuracy: 0.4539
# Epoch 19/40
# 400/400 [==============================] - 46s 115ms/step - loss: 0.1195 - accuracy: 0.9620 - val_loss: 3.1451 - val_accuracy: 0.4611
# Epoch 20/40
# 400/400 [==============================] - 46s 115ms/step - loss: 0.0928 - accuracy: 0.9707 - val_loss: 3.7793 - val_accuracy: 0.4768
# Epoch 21/40
# 400/400 [==============================] - 44s 111ms/step - loss: 0.1054 - accuracy: 0.9667 - val_loss: 3.6925 - val_accuracy: 0.4507
# Epoch 22/40
# 400/400 [==============================] - 44s 111ms/step - loss: 0.0984 - accuracy: 0.9691 - val_loss: 3.3147 - val_accuracy: 0.4865
# Epoch 23/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.0874 - accuracy: 0.9713 - val_loss: 4.3273 - val_accuracy: 0.4522
# Epoch 24/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.0740 - accuracy: 0.9767 - val_loss: 3.8071 - val_accuracy: 0.4617
# Epoch 25/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.0770 - accuracy: 0.9743 - val_loss: 3.4888 - val_accuracy: 0.4840
# Epoch 26/40
# 400/400 [==============================] - 46s 115ms/step - loss: 0.0811 - accuracy: 0.9735 - val_loss: 3.7408 - val_accuracy: 0.4702
# Epoch 27/40
# 400/400 [==============================] - 46s 115ms/step - loss: 0.0875 - accuracy: 0.9720 - val_loss: 3.9846 - val_accuracy: 0.4539
# Epoch 28/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.0609 - accuracy: 0.9809 - val_loss: 3.3693 - val_accuracy: 0.5000
# Epoch 29/40
# 400/400 [==============================] - 46s 115ms/step - loss: 0.0607 - accuracy: 0.9812 - val_loss: 4.1004 - val_accuracy: 0.4636
# Epoch 30/40
# 400/400 [==============================] - 44s 110ms/step - loss: 0.0695 - accuracy: 0.9780 - val_loss: 3.5284 - val_accuracy: 0.4874
# Epoch 31/40
# 400/400 [==============================] - 44s 111ms/step - loss: 0.0694 - accuracy: 0.9773 - val_loss: 3.2440 - val_accuracy: 0.5183
# Epoch 32/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.0588 - accuracy: 0.9806 - val_loss: 3.5029 - val_accuracy: 0.5116
# Epoch 33/40
# 400/400 [==============================] - 44s 110ms/step - loss: 0.0593 - accuracy: 0.9811 - val_loss: 3.5098 - val_accuracy: 0.5073
# Epoch 34/40
# 400/400 [==============================] - 44s 111ms/step - loss: 0.0563 - accuracy: 0.9816 - val_loss: 3.5105 - val_accuracy: 0.5045
# Epoch 35/40
# 400/400 [==============================] - 44s 111ms/step - loss: 0.0511 - accuracy: 0.9839 - val_loss: 3.8516 - val_accuracy: 0.4874
# Epoch 36/40
# 400/400 [==============================] - 46s 116ms/step - loss: 0.0597 - accuracy: 0.9801 - val_loss: 3.8690 - val_accuracy: 0.4873
# Epoch 37/40
# 400/400 [==============================] - 47s 117ms/step - loss: 0.0591 - accuracy: 0.9813 - val_loss: 3.5074 - val_accuracy: 0.5103
# Epoch 38/40
# 400/400 [==============================] - 47s 117ms/step - loss: 0.0570 - accuracy: 0.9814 - val_loss: 3.8764 - val_accuracy: 0.5011
# Epoch 39/40
# 400/400 [==============================] - 47s 117ms/step - loss: 0.0558 - accuracy: 0.9819 - val_loss: 3.4718 - val_accuracy: 0.5130
# Epoch 40/40
# 400/400 [==============================] - 45s 112ms/step - loss: 0.0415 - accuracy: 0.9866 - val_loss: 3.7440 - val_accuracy: 0.4923
# 313/313 [==============================] - 4s 12ms/step - loss: 3.6830 - accuracy: 0.4968
# Test accuracy: 0.4968000054359436
